# %%
from google.colab import drive
import folium
import pandas as pd
from folium import plugins
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = '/content/drive/MyDrive/Python Data Base/CCT/CCTracker.xlsx'

# %%
cc_df = pd.read_excel(data)
cc_df.columns
# Out:
# Index(['Complaint_Number', 'Latitude', 'Longitude'], dtype='object')

# %%
latitudes = list(cc_df.Latitude)
longitudes = list(cc_df.Longitude)
CC_num = list(cc_df.Complaint_Number)

# %%
cc_map = folium.Map(location=[latitudes, longitudes],zoom_start=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/folium/utilities.py in validate_location(location)
#      59         try:
# ---> 60             float(coord)
#      61         except (TypeError, ValueError):
#
# TypeError: float() argument must be a string or a number, not 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f312a79efff4> in <module>
# ----> 1 cc_map = folium.Map(location=[latitudes, longitudes],zoom_start=12)
#
# ...
